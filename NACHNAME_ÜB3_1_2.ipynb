# %% [markdown]
# [624.605, Basiskompetenzen: Propädeutikum zur Programmierung @ Schuschnig]

# %% [markdown]
# **Duplizieren Sie und füllen Sie das Formular aus oder laden Sie ihre Lösung in Moodle hoch!**

# %% [markdown]
# # Übungsblatt 3 - (input) & Schleifen & Listen

# %% [markdown]
# ### Übung 1 - Zahlenprüfung - if-else

# %% [markdown]
# **A)** Erstellen Sie ein Python-Programm, das eine Eingabezahl überprüft. Verwenden Sie eine Nummber (integer) Variable für die Anwendung. Erstellen Sie ein Python-Programm, das eine Zahl von der Kommandozeile liest und ausgibt, ob die Eingabe
#
#   1) **negativ** --> "Die eingegebene Zahl ist negativ."
#
#   2) **positiv** --> "Die eingegebene Zahl ist positiv."
#
#   oder 3) **Null** --> "Die eingegebene Zahl ist 0."

# %%
# Übung A)
# Schreiben Sie hier Ihren Code hier

# %% [markdown]
# **B)**
# Schreibe ein zweites Java-Programm, das die Summe zweier ganzer Zahlen berechnet und "true" zurückgibt, wenn die Summe gleich einer dritten ganzen Zahl ist, andernfalls "false".

# %%
# Übung B)
# Schreiben Sie hier Ihren Code hier

# %% [markdown]
# **Beispielhafte Ausgabe bei Eingabe der Zahlen 5, 10, 15:**
#
# * Eingabe der ersten Zahl: *5*
# * Eingabe der zweiten Zahl: *10*
# * Geben Sie die dritte Zahl ein: *15*
# * Das Ergebnis ist: True

# %% [markdown]
# ### Übung 2 - Umwandlung eines Flussdiagramms in eine Python-Anwendung

# %% [markdown]
# Implementieren Sie das folgende Flussdiagramm als Python-Programm (Sie kennen es aus Übungsblatt 1).
#
# Das Bild finden Sie auf Moodle mit dem Namen ("ÜB3_Aufgabe1.png")
#
# Testen Sie die Anwendung mit verschiedenen Eingabezahlen.
#
#
# **Hinweis: Verwenden Sie die `for` schleife.**

# %%
# Übung
# Schreiben Sie hier Ihren Code für Übung  hier

# %% [markdown]
# ---

# %% [markdown]
# ### Übung 3 - Multiplikationstabelle mit for-Schleife

# %% [markdown]
# Schreiben Sie ein Programm, das die Multiplikationstabelle für eine vom Benutzer eingegebene Zahl ausgibt.
# Die Tabelle soll von 1 bis 10 gehen.
#
# **Hinweis: Nutzen Sie eine for-Schleife mit range() und formatieren Sie die Ausgabe übersichtlich.**

# %%
# Übung
# Schreiben Sie hier Ihren Code für Übung  hier

# %% [markdown]
# Beispielhafte Ausgabe bei Eingabe der Zahl **5**
#
# ```
# Multiplikationstabelle für 5:
#
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# ```

# %% [markdown]
# ### Übung 4 - Listen - Tiere

# %% [markdown]
# Erstellen Sie eine beliebige Liste mit den Namen von fünf Tieren. Schreiben Sie ein Programm, das:
#
# 1. Alle Tiere in der Liste ausgibt.
# 2. Die Anzahl der Tiere in der Liste anzeigt.
# 3. Den Namen des ersten und die letzten beiden Tiers in der Liste ausgibt.
# 4. Ersetzen Sie ein beliebiges Tier mit "Kröte"
# 5. Drehen Sie die Liste mit reverse() um
# 6. Verwenden Sie nun die Listenfunktion index(), um die Position von "Kröte" zu finden
# 7. geben Sie danach die Liste wieder aus

# %%
# Übung
# Schreiben Sie hier Ihren Code für Übung  hier

# %% [markdown]
# ### Übung 5 - Ausgabe von Zahlen
#
# **A)**
# Schreiben Sie ein Programm, das Zahlen zwischen 10 und 100 ausgibt, die durch 3 teilbar sind, und verwenden Sie eine For-Schleife.

# %%
# Übung
# Schreiben Sie hier Ihren Code für Übung  hier

# %% [markdown]
# Beispielhafte Ausgabe:
#
# > Geteilte Zahlen zwischen 10 und 100:
# 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99

# %% [markdown]
# **B)** Kopieren Sie Ihren Code von Aufgabe A)
#
# Die gleichen Zahlen ausgegeben werden mit Ausnahme der Werte 30, 51 und 66

# %%
# Übung
# Schreiben Sie hier Ihren Code für Übung  hier

# %% [markdown]
# ### Übung 6: Die Schatztruhe des Abenteurers – Hilf dem Abenteurer beim Sortieren!
#
# Ein tapferer Abenteurer kehrt von seiner Reise zurück und bringt eine Schatztruhe voller exotischer Fundstücke mit. In der Truhe befinden sich Goldmünzen, wertvolle Artefakte, mysteriöse Elixiere und uralte Schriftrollen. Der Abenteurer bittet dich, die Truhe zu sortieren und die Schätze in passende Fächer zu legen, um sie besser verwalten zu können.
#
# Sortiere die Gegenstände in passende Fächer:
#
#     goldmuenzen für Zahlen (int)
#     elixiere für Fließkommazahlen (float)
#     artefakte für Strings (str)
#     amulette für Booleans (bool)
#
# Schreibe ein Programm, das die Schatztruhe durchläuft, die Gegenstände analysiert und sie in die entsprechenden Fächer legt.

# %%
# Übung
# Schreiben Sie hier Ihren Code für Übung hier

# %% [markdown]
# B) Abenteurer-Bericht:
# Der Abenteurer möchte am Ende einen Bericht über die Schätze. Gib für jedes Fach aus, wie viele Gegenstände es enthält:
# ```
# Die Schatztruhe enthält:
# - 6 Goldmünzen
# - 4 Elixiere
# - 8 Artefakte
# - 2 Amulette
# ```

# %%
# Übung
# Schreiben Sie hier Ihren Code für Übung hier
