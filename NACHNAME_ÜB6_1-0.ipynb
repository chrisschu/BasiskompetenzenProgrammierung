# %% [markdown]
# [624.605, Basiskompetenzen: Propädeutikum zur Programmierung @ Schuschnig]

# %% [markdown]
# **Duplizieren Sie und füllen Sie das Formular aus und Ausarbeitungen als zip-Datei oder .ipynb-Datei in Moodle hoch!**

# %% [markdown]
# # Übungsblatt 6 - Klasse und Objekte

# %% [markdown]
# ### Übung 1 - Maximum aus einer Liste ausgeben

# %% [markdown]
# Zeichnen Sie die Klasse Aircraft in einem UML-Klassendiagramm (als seperate PDF-Datei).
#
# Die folgenden Instanzvariablen und Methoden sollten enthalten sein:
#
# **Instanzvariablen:**
# *    Typ
# *    numberOfSeats
# *    numberOfWheels
# *    Bereich
# *    numberOfEngines
# *    currentSpeed
#
# **Methoden:**
# *    beschleunigen()
# *    Bremse()
# *    takeOff()
# *    landen()

# %% [markdown]
# ### Übung 2 - Erstellung der Klasse Aircraft

# %% [markdown]
# Implementieren Sie die Klasse Aircraft mit allen Instanzvariablen und Methoden aus der Aufgabe 1.
#
# Die Funktionsweise der Methode sollten folgendes beeinhalten:
#
# *   accelerate() - Sollte folgende Ausgabe auf der Konsole ausgeben ("Das Flugzeug
# *   beschleunigt..."). Die currentSpeed sollte einen um 100 erhöhten Wert erhalten.
# *   break() - Sollte folgende Ausgabe auf der Konsole ausgeben ("Das Flugzeug bremst..."). Die Instanzvariable currentSpeed sollte einen um 100 verringerten Wert erhalten.
# *   takeOff() - Sollte folgende Ausgabe auf der Konsole ausgeben ("Das Flugzeug hebt ab...")
# *   land() - Sollte folgende Ausgabe auf der Konsole ausgeben ("Das Flugzeug landet...")
# *   printInformation() - Diese Methode sollte Informationen über Ihr Flugzeugobjekt liefern und die Werte der Instanzvariablen ausgeben.

# %%
# Übung 2)
# Schreiben Sie hier Ihren Code für Übung 2) hier

# %% [markdown]
# ---

# %% [markdown]
# ### Übung 3 - Erstellen

# %% [markdown]
# Implementieren eine reale Instanz / Objekt und erstellen Sie ein Aircraft-Objekt.
#
# Weisen Sie allen Instanzvariablen (z.B. numberOfSeats = 300) Ihres neu erstellten Aircraft-Objekts sinnvolle Werte zu und führen Sie alle Methoden des Objekts aus (accelerate(), brake(), takeOff(), land(), printInformation()).
#
# Führen Sie den AircraftTest aus.

# %%
# Übung 3)
# Schreiben Sie hier Ihren Code für Übung 3) hier
