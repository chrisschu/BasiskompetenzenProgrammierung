# %% [markdown]
# # [624.605, Basiskompetenzen: Propädeutikum zur Programmierung @ Schuschnig]

# %% [markdown]
# **Füllen Sie diese Datei aus, benennen Sie Datei mit Ihrem Nachnamen um und laden Sie die Datei in Moodle hoch!**

# %% [markdown]
# # Übung 3 - Ausführen von Python-Dateien in Google Colab
#
# Erinnern Sie sich an die Programmieraufgabe, die wir in der Lektion (Chapter 2 / Folie 28/29) besprochen haben?
#
# Erweitern Sie das dazugehörige Python-Programm, das die Werte von drei Variablen vertauscht.
#
# Verwenden Sie zwei verschiedene Print-Methoden, die wir kennengelernt haben.
#
# Gegeben sind zwei Variablen
#
# *   var1 hat den Wert 100
# *   var2 hat den Wert 200
# *   var3 hat den Wert 300
#
# Die Ausgabe der Anwendung sollte sein:
#
# ```
# var1 hat den Wert 300
# var2 hat den Wert 200
# var3 hat den Wert 100
# ```
#
# **Kombinieren Sie jeweils Textzeichen und den Wert der Variable (sollte dynamisch veränderbar sein) in einer Zeile**

# %%
# Übung 3
# Lösung für die Übung bitte hier eingeben
