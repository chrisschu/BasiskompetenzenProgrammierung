# %% [markdown]
# # [624.605, Basiskompetenzen: Propädeutikum zur Programmierung @ Schuschnig]

# %% [markdown]
# **Füllen Sie diese Datei aus, benennen Sie Datei mit Ihrem Nachnamen um und laden Sie die Datei in Moodle hoch!**

# %% [markdown]
# # Übungsblatt 3 - Python-Grundlagen Variablen & if

# %% [markdown]
# ### Übung 3 - Wochentage - if-else-Konstruktion

# %% [markdown]
# Schreiben Sie eine Anwendung, bei der eine Variable geprüft wird: Je nachdem welchen Wert die Variable hat, wird der richtige Wochentag ausgegeben.
#
# Zum Beispiel sollte 1 "Montag" ausgeben, 2 "Dienstag" und so weiter, bis zu 7, die "Sonntag" ausgeben sollte.
#
# Wenn der Benutzer eine Zahl außerhalb dieses Bereichs eingibt, sollte die Ausgabe "keine gültige Zahl" lauten.
#
# **Hinweis: Verwenden Sie eine geeignete if-else-Konstruktion, um diese Aufgabe zu erfüllen.**

# %%
# Übung
# Schreiben Sie hier Ihren Code

# %% [markdown]
# ---

# %% [markdown]
# ### Übung 4 - Einfache Java-Anwendung - Beispiel aus dem Mittelalter

# %% [markdown]
# Erstellen Sie ein Python-Programm für ein mittelalterliches Einkaufsabenteuer.
#
# Ihr Programm sollte die Gesamtkosten, die Steuer und die Endrechnung für magische Artikel berechnen und anzeigen.
#
# 1. Wählen Sie drei Ausrüstungsgegenstände mit unterschiedlichen Goldwerten (z.B. Helm, Rüstung, Schild, Schwert, ...).
# 2. Berechnen Sie die Gesamtkosten der Artikel.
# 3. Für jede Transaktion wird eine zusätzliche Steuer von 15 Goldmünzen erhoben.
# 4. Zeigen Sie eine Begrüßungsnachricht, die Details der einzelnen Artikel und die endgültige Rechnung an.

# %% [markdown]
# **Hinweis:**
# **Verwenden Sie für die Implementierung nur Konstrukte, die Sie bereits kennen (keine Dictionarys, Schleifen oder dergleichen).**
#
# **Es ist in dieser Übung kein input()-Methode notwendig**

# %%
# Übung
# Schreiben Sie hier Ihren Code

# %% [markdown]
# ---
